# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement_targets.csv')
df2 = pd.read_csv('indian_engineering_student_placement.csv')

# %%
print("Shape :",df.shape)
print("Size :",df.size)
print("Information :",df.info)
print("Columns :",df.columns)
# Out:
# Shape : (5000, 3)
# Size : 15000
# Information : <bound method DataFrame.info of       Student_ID placement_status  salary_lpa
# 0              1           Placed       14.95
# 1              2           Placed       14.91
# 2              3           Placed       17.73
# 3              4           Placed       14.52
# 4              5           Placed       15.91
# ...          ...              ...         ...
# 4995        4996           Placed       19.35
# 4996        4997       Not Placed        0.00
# 4997        4998           Placed       19.13
# 4998        4999           Placed       16.53
# 4999        5000           Placed       20.00
#
# [5000 rows x 3 columns]>
# Columns : Index(['Student_ID', 'placement_status', 'salary_lpa'], dtype='object')

# %%
df.head()
# Out:
#    Student_ID placement_status  salary_lpa
# 0           1           Placed       14.95
# 1           2           Placed       14.91
# 2           3           Placed       17.73
# 3           4           Placed       14.52
# 4           5           Placed       15.91

# %%
df.tail()
# Out:
#       Student_ID placement_status  salary_lpa
# 4995        4996           Placed       19.35
# 4996        4997       Not Placed        0.00
# 4997        4998           Placed       19.13
# 4998        4999           Placed       16.53
# 4999        5000           Placed       20.00

# %% [markdown]
# df2 -> student.csv

# %%
print("Shape :",df2.shape)
print("Size :",df2.size)
print("Information :",df2.info)
print("Columns :",df2.columns)
# Out:
# Shape : (5000, 23)
# Size : 115000
# Information : <bound method DataFrame.info of       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 0              1    Male    ECE   8.74              74.0                75.0
# 1              2  Female    ECE   7.80              75.3                69.7
# 2              3  Female     IT   6.95              62.8                68.3
# 3              4    Male    ECE   7.46              57.9                51.4
# 4              5    Male     IT   6.86              61.3                73.5
# ...          ...     ...    ...    ...               ...                 ...
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4996        4997    Male     IT   7.76              74.3                72.6
# 4997        4998    Male     IT   7.79              64.0                71.2
# 4998        4999  Female    ECE   8.76              74.3                74.0
# ...

# %%
df2.head()
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
# 2           3  Female     IT  6.95              62.8                68.3
# 3           4    Male    ECE  7.46              57.9                51.4
# 4           5    Male     IT  6.86              61.3                73.5
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
# 2         0                  1.5                   62.5                   8
# 3         1                  4.7                   64.6                   6
# 4         2                  5.2                   75.9                   3
#
# ...

# %%
df2.tail()
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4996        4997    Male     IT   7.76              74.3                72.6
# 4997        4998    Male     IT   7.79              64.0                71.2
# 4998        4999  Female    ECE   8.76              74.3                74.0
# 4999        5000    Male    CSE   9.45              85.6                80.0
#
#       backlogs  study_hours_per_day  attendance_percentage  \
# 4995         0                  3.7                   75.3
# 4996         2                  6.3                   72.3
# 4997         2                  2.0                   63.8
# 4998         0                  5.1                   72.0
# 4999         0                  2.8                   63.4
#
#       projects_completed  ...  aptitude_skill_rating  hackathons_participated  \
# ...
